# %% [markdown]
# <a href="https://colab.research.google.com/github/Soflin3/datascience/blob/main/Untitled-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")

# %%
print("Connecting Colab and Git")
